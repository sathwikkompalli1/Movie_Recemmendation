# %% [markdown]
# # Movie Recommendation System - PHASE 7: Model Deployment
#
# ## Overview
# This notebook handles:
# 1. **Model Serialization**: Save all trained models to disk
# 2. **Inference Pipeline**: Create `movie_recommender.py` script
# 3. **API Server**: FastAPI backend for real-time recommendations
# 4. **Frontend**: Interactive HTML interface for recommendations

# %%
# Import libraries
import pickle
import json
import os
import pandas as pd
import numpy as np

print("✓ Libraries imported!")
# Out:
# ✓ Libraries imported!

# %% [markdown]
# ## Section 1: Load Final Models and Create Deployment Package
